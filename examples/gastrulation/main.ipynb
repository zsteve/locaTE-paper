# %%
import scvelo as scv
import scanpy as sc
adata = scv.datasets.gastrulation()

# %%
sc.pl.scatter(adata, basis = "umap", color = "celltype")

# %%
adata_subset = adata[adata.obs.celltype.isin(['Blood progenitors 1', 'Blood progenitors 2', 'Haematoendothelial progenitors',])]

# %%
sc.pl.scatter(adata_subset, basis = "umap", color = "Spi1")

# %%
sc.pl.scatter(adata_subset, basis = "umap", color = "Gata1")

# %%
sc.pl.scatter(adata_subset, basis = "umap", color = "Gata2")
